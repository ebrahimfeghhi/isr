# %%
import sys
sys.path.append('/home3/ebrahim/isr/')
from RNNcell import RNN_one_layer, RNN_two_layers
import torch.nn as nn
import numpy as np
from matplotlib import pyplot as plt

# %%
A = np.random.uniform(-1, 1, 100).reshape(10,10)
print(A.shape)

w, v = np.linalg.eig(A)
print(w)
# Out:
# (10, 10)
# [-0.42278985+1.52405473j -0.42278985-1.52405473j -1.39096444+0.j
#  -1.20560518+0.j          1.54446936+0.86037354j  1.54446936-0.86037354j
#   1.45658643+0.j          0.42442123+0.75191603j  0.42442123-0.75191603j
#   0.0815038 +0.j        ]

# %%
model = RNN_one_layer(11, 200, 11, 1.0)
for param in model.parameters():
    print(param.shape)
    plt.hist(param.detach().cpu().numpy().ravel())
    plt.plot()
    plt.show()
# Out:
# torch.Size([200, 200])
# torch.Size([200])
# torch.Size([200, 11])
# torch.Size([200, 11])
# torch.Size([11, 200])
# torch.Size([11])
